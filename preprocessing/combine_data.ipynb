# %%
import re
import pandas as pd

# %%
raw_url1 = 'https://raw.githubusercontent.com/SendShieldLaskarAI/SendShield-Machine-Learning/25244aabf6d19daefe3d6d0c35ee4189ba4628e8/data/bully%20(1).csv'
raw_url2 = 'https://raw.githubusercontent.com/SendShieldLaskarAI/SendShield-Machine-Learning/8466386ac7875996ac13f778d588d58145079d9a/data/bully1.old.csv'

try:
    data1 = pd.read_csv(raw_url1, on_bad_lines='skip', encoding='utf-8')
    print("Successfully loaded data1")
    print(f"Shape: {data1.shape}")
except Exception as e:
    print(f"Error loading data1: {e}")
    data1 = None

try:
    data2 = pd.read_csv(raw_url2, on_bad_lines='skip', encoding='utf-8')
    print("Successfully loaded data2")
    print(f"Shape: {data2.shape}")
except Exception as e:
    print(f"Error loading data2: {e}")
    data2 = None
# Out:
# Successfully loaded data1
# Shape: (18874, 1)
# Successfully loaded data2
# Shape: (473, 15)

# %%
data1
# Out:
#                                                  Comment
# 0       Mending plonga plong Tinimbang pinter go minteri
# 1                        Hidup amin Raiso bapa repormasi
# 2                           Mantaappps... Btlllll pak...
# 3                          Yang menghina itu lambemu min
# 4      Amin rais manusia paling redah pikiranya..peng...
# ...                                                  ...
# 18869                                   Gih leres pak...
# 18870                                        Fakta nyata
# 18871  As min rdis prof terbodoh hj del UI ruh 😊dunia...
# 18872                             Mbah kemin...nglindur😂
# 18873                                           betul tu
#
# [18874 rows x 1 columns]

# %%
data2
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1917575098586005618  Wed Apr 30 23:58:26 +0000 2025              10
# 1    1917415198232899691  Wed Apr 30 23:58:22 +0000 2025               0
# 2    1917497936336019725  Wed Apr 30 23:58:15 +0000 2025               0
# 3    1917021009687023781  Wed Apr 30 23:58:14 +0000 2025               0
# 4    1917542401801072903  Wed Apr 30 23:58:03 +0000 2025               0
# ..                   ...                             ...             ...
# 468  1917495981022797837  Wed Apr 30 22:28:18 +0000 2025               1
# 469  1917540195563626502  Wed Apr 30 22:28:01 +0000 2025               0
# 470  1917593086504624425  Wed Apr 30 22:27:42 +0000 2025               1
# 471  1917516454888616259  Wed Apr 30 22:27:37 +0000 2025               0
# 472  1917175371461722566  Wed Apr 30 22:27:23 +0000 2025               0
#
#                                              full_text               id_str  \
# ...

# %%
data1['text'] = data1['Comment']
data1
# Out:
#                                                  Comment  \
# 0       Mending plonga plong Tinimbang pinter go minteri
# 1                        Hidup amin Raiso bapa repormasi
# 2                           Mantaappps... Btlllll pak...
# 3                          Yang menghina itu lambemu min
# 4      Amin rais manusia paling redah pikiranya..peng...
# ...                                                  ...
# 18869                                   Gih leres pak...
# 18870                                        Fakta nyata
# 18871  As min rdis prof terbodoh hj del UI ruh 😊dunia...
# 18872                             Mbah kemin...nglindur😂
# 18873                                           betul tu
#
#                                                     text
# 0       Mending plonga plong Tinimbang pinter go minteri
# 1                        Hidup amin Raiso bapa repormasi
# 2                           Mantaappps... Btlllll pak...
# ...

# %%
data2['text'] = data2['full_text']
data2
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1917575098586005618  Wed Apr 30 23:58:26 +0000 2025              10
# 1    1917415198232899691  Wed Apr 30 23:58:22 +0000 2025               0
# 2    1917497936336019725  Wed Apr 30 23:58:15 +0000 2025               0
# 3    1917021009687023781  Wed Apr 30 23:58:14 +0000 2025               0
# 4    1917542401801072903  Wed Apr 30 23:58:03 +0000 2025               0
# ..                   ...                             ...             ...
# 468  1917495981022797837  Wed Apr 30 22:28:18 +0000 2025               1
# 469  1917540195563626502  Wed Apr 30 22:28:01 +0000 2025               0
# 470  1917593086504624425  Wed Apr 30 22:27:42 +0000 2025               1
# 471  1917516454888616259  Wed Apr 30 22:27:37 +0000 2025               0
# 472  1917175371461722566  Wed Apr 30 22:27:23 +0000 2025               0
#
#                                              full_text               id_str  \
# ...

# %%
combined_data = pd.concat([data1['text'], data2['text']], ignore_index=True)
combined_data.to_csv('datafull.csv', index=False)

# %%
data = pd.read_csv('datafull.csv')
data
# Out:
#                                                     text
# 0       Mending plonga plong Tinimbang pinter go minteri
# 1                        Hidup amin Raiso bapa repormasi
# 2                           Mantaappps... Btlllll pak...
# 3                          Yang menghina itu lambemu min
# 4      Amin rais manusia paling redah pikiranya..peng...
# ...                                                  ...
# 19342  @kompascom Tapi aiman bertanya ke pengacaranya...
# 19343  @muannas_alaidid Yg jelas omongannya Jokowi pa...
# 19344                      @CakKhum depresi si om Jokowi
# 19345  @TriSartopo @ch_chotimah2 @jokowi Mana berani ...
# 19346  @powerangerpink7 @sarwonobs @DokterTifa @jokow...
#
# [19347 rows x 1 columns]
